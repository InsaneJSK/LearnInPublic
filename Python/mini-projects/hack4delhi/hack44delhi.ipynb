# %%
from bs4 import BeautifulSoup
import requests
soup = BeautifulSoup(requests.get("https://traffic.delhipolice.gov.in/water-logging-area").text)

# %%
soup.find("tbody").find_all("tr")[79].find_all("td")[3].text.strip()
# Out:
# '21.08.2021\n11.09.2021'

# %%
import csv
file = open("delhi_water_logging_areas.csv", "w", newline='', encoding='utf-8')
writer = csv.writer(file)
colhead = soup.find("tbody").find_all("tr")[0].find_all("td")
writer.writerow([col.text.strip() for col in colhead])
# Out:
# 59

# %%
for row in soup.find("tbody").find_all("tr")[1::]:
    cols = row.find_all("td")
    writer.writerow([cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip().split("\n"), cols[4].text.strip()])

# %%
file.close()

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm


# -----------------------------
# Create geocoder
# -----------------------------
geolocator = Nominatim(user_agent="monsoon-readiness-hackathon")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
# -----------------------------
# Load your CSV
# -----------------------------
df = pd.read_csv("delhi_water_logging_areas.csv")

# -----------------------------
# Build full query per row
# -----------------------------
def build_query(row):
    parts = []

    if pd.notna(row.get("Specific location")) and str(row["Specific location"]).strip() not in ["--", "-"]:
        parts.append(str(row["Specific location"]))

    if pd.notna(row.get("Name of the Road")):
        parts.append(str(row["Name of the Road"]))

    parts.append("Delhi, India")

    return ", ".join(parts)

latitudes = []
longitudes = []

print("Starting geocoding...\n")

# Add tqdm progress bar
for idx, row in tqdm(df.iterrows(), total=len(df), desc="Geocoding locations"):
    query = build_query(row)

    try:
        # verbose print
        print(f"🔍 Querying: {query}")

        location = geocode(query)

        if location:
            latitudes.append(location.latitude)
            longitudes.append(location.longitude)
            print(f"✅ Found: ({location.latitude}, {location.longitude})\n")
        else:
            latitudes.append(None)
            longitudes.append(None)
            print("⚠️ No result found\n")

    except Exception as e:
        latitudes.append(None)
        longitudes.append(None)
        print(f"❌ Error: {e}\n")

# -----------------------------
# Save results
# -----------------------------
df["latitude"] = latitudes
df["longitude"] = longitudes

df.to_csv("waterlogging_with_coordinates.csv", index=False)

print("\n🎉 Done! Saved as waterlogging_with_coordinates.csv")

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm
import re

df = pd.read_csv("D:\me\CODING\Github\DeepRed\delhi_water_logging_areas.csv")

geolocator = Nominatim(user_agent="monsoon-readiness-hackathon")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

def clean_text(s):
    if pd.isna(s):
        return ""
    s = str(s)

    # remove brackets / quotes
    s = re.sub(r"[\[\]']", "", s)

    junk_words = [
        "Near", "near",
        "towards",
        "both carriageway",
        "carriageway",
        "Redlight",
        "roundabout",
        "loop",
        "--"
    ]
    for w in junk_words:
        s = s.replace(w, "")

    # collapse double spaces
    s = re.sub(r"\s+", " ", s)

    return s.strip()

latitudes = []
longitudes = []

print("\n🚀 Starting geocoding (Delhi-biased, no bounding box)...\n")

for idx, row in tqdm(df.iterrows(), total=len(df), desc="Geocoding"):
    loc = clean_text(row.get("Specific location"))
    road = clean_text(row.get("Name of the Road"))

    candidates = [
        f"{loc}, {road}, New Delhi, Delhi, India",
        f"{road}, New Delhi, Delhi, India",
        f"{loc}, New Delhi, Delhi, India",
        f"{road}, Delhi, India",
        f"{loc}, Delhi, India"
    ]

    found = False

    for q in candidates:
        if len(q.replace(",", "").strip()) == 0:
            continue

        print(f"🔍 Trying: {q}")

        try:
            location = geocode(q)

            if location:
                latitudes.append(location.latitude)
                longitudes.append(location.longitude)
                print(f"✅ Found: ({location.latitude}, {location.longitude})\n")
                found = True
                break

        except Exception as e:
            print(f"❌ Error: {e}")

    if not found:
        latitudes.append(None)
        longitudes.append(None)
        print("⚠️ No match after all fallbacks\n")

df["latitude"] = latitudes
df["longitude"] = longitudes

df.to_csv("waterlogging_with_coordinates_WORKING.csv", index=False)

print("\n🎉 Done! Saved as waterlogging_with_coordinates_WORKING.csv\n")

# %%
df = pd.read_csv("D:\me\CODING\Github\DeepRed\waterlogging_with_coordinates_WORKING.csv")

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Sl. No.                       Name of the Road  \
# 0        1.0                     Africa Avenue Road
# 13      14.0                         Aurobindo Marg
# 24      25.0             Choudhary Fateh Singh Marg
# 26      27.0    DDU Marg (Deen Dayal Upadhyay Marg)
# 27      28.0             Dr. Bhim Rao Ambedkar Road
# 28      29.0              Drain Road (Dabri-Dwarka)
# 35      36.0              Girdhari Lal Goswami Marg
# 36      37.0                  GT Road / Old GT Road
# 37      38.0                  GT Road / Old GT Road
# 38      39.0                  GT Road / Old GT Road
# 40      41.0                  GT Road / Old GT Road
# 41      42.0                  GT Road / Old GT Road
# 42      43.0                               GTK Road
# 44      45.0                               GTK Road
# 45      46.0                               GTK Road
# 46      47.0                               GTK Road
# 47      48.0                               GTK Road
# 53      54.0                    Kemal Attaturk Marg
# 61      62.0                   Lampur – Narela Road
# 70      71.0   M.G. Road (Mehrauli – Gurugram Road)
# 71      72.0   M.G. Road (Mehrauli – Gurugram Road)
# 82      83.0            Mother Teresa Crescent Marg
# 84      85.0            Mother Teresa Crescent Road
# 85      86.0            Mother Teresa Crescent Road
# 87      88.0            Mother Teresa Crescent Road
# 88      89.0                    Moti Lal Nehru Marg
# 89      90.0                        Mubarakpur Road
# 95      96.0                   Najafgarh Firni Road
# 107    108.0                        Nitya Nand Marg
# 151    152.0                   Road No. 226, Dwarka
# 152    153.0                            Road No. 57
# 172    173.0           Shyama Prasad Mukherjee Marg
# 173    174.0           Shyama Prasad Mukherjee Marg
# 174    175.0                      South Avenue Road
# 183    184.0                             Tilak Marg
# 187    188.0                      Vandemataram Marg
# 188    189.0                Veer Banda Bairagi Marg
# 196    197.0                              DAVP Marg
# 201    202.0                    NH-48 Gurugram Road
# 204    205.0                         J.B. Tito Marg
# 206    207.0  Jhilmil Industrial Area, Railway Road
#
#                                      Specific location  \
# 0            Both carriageway Madhav Rao Schindia Marg
# 13                               Near Adhchini Village
# 24   Near P.S. Timarpur (both carriageway) / Wazira...
# 26                                             W-Point
# 27                                Bhim Gali, Malkaganj
# 28   Drain Road at various locations between Power ...
# 35                            Near Post Office Naraina
# 36   Between Dharampura and Iron Bridge / near Iron...
# 37                                Dharampura Seelampur
# 38   Near Seelampur Flyover  (Shastri Park to Shahd...
# 40                                      Shahdara Mandi
# 41                Shastri Park to Shahdara carriageway
# 42                                  Azad Pur underpass
# 44                                  Libaspur Underpass
# 45                                  Near GTK DTC Depot
# 46                    Near Jahangir Puri Metro Station
# 47                              Shakti Nagar underpass
# 53                                  Near Bhinder Point
# 61                                    Lampur Underpass
# 70                           Andheria Mor to M.G. Road
# 71                        Near Jain Mandir Qutub Minar
# 82                 Infront of Gate No. 31, R.P. Bhawan
# 84                        Near RML Hospital roundabout
# 85                                     Near RML U-Turn
# 87   Redlight Sardar Patel Marg towards Ram Manohar...
# 88                         Q-Point Moti Lal Nehru Marg
# 89        Nangloi Railway Phatak to Mubarakpur village
# 95                                          Firni Road
# 107        Near Gate No. 3 Kashmere Gate metro station
# 151                       Sector-20 near Marble Market
# 152                    Bihari Colony Railway underpass
# 172             Exit gate of Old Delhi Railway Station
# 173                                   Near Chhata Rail
# 174                        Both side South Avenue Road
# 183                                 Under Tilak Bridge
# 187                            Roundabout Shankar Road
# 188                              Azad Market underpass
# 196                                           CISF Cut
# 201                                     Sanjay T-Point
# 204                        Central School Andrewz Ganj
# 206                           Kasturba Nagar Underpass
#
#                                                   Date  Frequency   latitude  \
# 0                                       ['01.09.2021']        1.0        NaN
# 13                                      ['11.09.2021']        NaN  28.575792
# 24                        ['29.07.2021', '01.08.2021']        2.0        NaN
# 26                                      ['31.08.2021']        1.0        NaN
# 27                        ['01.08.2021', '01.09.2021']        2.0        NaN
# 28                                      ['13.07.2021']        1.0        NaN
# 35                                      ['11.09.2021']        NaN  28.638762
# 36   ['03.07.2021', '14.07.2021', '19.07.2021', '29...        5.0        NaN
# 37                        ['19.07.2021', '28.07.2021']        2.0        NaN
# 38   ['03.07.2021', '19.07.2021', '28.07.2021', '30...        5.0        NaN
# 40                                      ['01.08.2021']        1.0        NaN
# 41                                      ['14.07.2021']        1.0        NaN
# 42   ['13.07.2021', '14.07.2021', '01.08.2021', '11...        4.0        NaN
# 44                                      ['11.09.2021']        1.0        NaN
# 45                        ['03.09.2021', '11.09.2021']        2.0        NaN
# 46                                      ['11.09.2021']        1.0        NaN
# 47                                      ['01.08.2021']        1.0        NaN
# 53                                      ['11.09.2021']        1.0        NaN
# 61                                      ['11.09.2021']        1.0        NaN
# 70                                      ['13.07.2021']        1.0        NaN
# 71                                      ['01.09.2021']        1.0        NaN
# 82                                      ['02.09.2021']        1.0        NaN
# 84                                      ['11.09.2021']        1.0        NaN
# 85                                      ['01.09.2021']        1.0        NaN
# 87                                      ['13.07.2021']        1.0        NaN
# 88                                      ['31.08.2021']        1.0        NaN
# 89                                      ['19.07.2021']        1.0        NaN
# 95                                      ['19.07.2021']        1.0        NaN
# 107                                     ['14.07.2021']        1.0        NaN
# 151                                     ['11.09.2021']        NaN  28.565182
# 152                       ['01.08.2021', '11.09.2021']        2.0        NaN
# 172                                     ['02.09.2021']        1.0        NaN
# 173         ['14.07.2021', '21.08.2021', '31.08.2021']        3.0        NaN
# 174                                     ['01.09.2021']        1.0        NaN
# 183                                     ['11.09.2021']        NaN  28.622307
# 187                                     ['08.08.2021']        1.0        NaN
# 188  ['14.07.2021', '08.08.2021', '21.08.2021', '01...        5.0        NaN
# 196                                     ['21.08.2021']        1.0        NaN
# 201                                     ['21.08.2021']        1.0        NaN
# 204                                     ['21.08.2021']        1.0        NaN
# 206                                     ['21.08.2021']        1.0        NaN
#
#      longitude
# 0          NaN
# 13   77.209784
# 24         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 35   77.143124
# 36         NaN
# 37         NaN
# 38         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 53         NaN
# 61         NaN
# 70         NaN
# 71         NaN
# 82         NaN
# 84         NaN
# 85         NaN
# 87         NaN
# 88         NaN
# 89         NaN
# 95         NaN
# 107        NaN
# 151  77.059724
# 152        NaN
# 172        NaN
# 173        NaN
# 174        NaN
# 183  77.239431
# 187        NaN
# 188        NaN
# 196        NaN
# 201        NaN
# 204        NaN
# 206        NaN

# %%
import pandas as pd
import ast   # to safely parse list-like strings

def count_dates(x):
    if pd.isna(x):
        return None
    
    try:
        # convert "['a','b']" -> ['a','b']
        parsed = ast.literal_eval(x)
        
        # if it's a list, return its length
        if isinstance(parsed, list):
            return len(parsed)
        
        # otherwise default to 1
        return 1
    
    except Exception:
        return 1

# apply only where Frequency is null
mask = df["Frequency"].isna()

df.loc[mask, "Frequency"] = df.loc[mask, "Date"].apply(count_dates)

# optionally convert Frequency to int
df["Frequency"] = df["Frequency"].astype(int)

# save back
df.to_csv("waterlogging_updated.csv", index=False)

print("Done — saved as waterlogging_updated.csv")
# Out:
# Done — saved as waterlogging_updated.csv

# %%
import pandas as pd
df = pd.read_csv("D:\me\CODING\Github\DeepRed\waterlogging_updated.csv")

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Sl. No.                       Name of the Road  \
# 0        1.0                     Africa Avenue Road
# 24      25.0             Choudhary Fateh Singh Marg
# 26      27.0    DDU Marg (Deen Dayal Upadhyay Marg)
# 27      28.0             Dr. Bhim Rao Ambedkar Road
# 28      29.0              Drain Road (Dabri-Dwarka)
# 36      37.0                  GT Road / Old GT Road
# 37      38.0                  GT Road / Old GT Road
# 38      39.0                  GT Road / Old GT Road
# 40      41.0                  GT Road / Old GT Road
# 41      42.0                  GT Road / Old GT Road
# 42      43.0                               GTK Road
# 44      45.0                               GTK Road
# 45      46.0                               GTK Road
# 46      47.0                               GTK Road
# 47      48.0                               GTK Road
# 53      54.0                    Kemal Attaturk Marg
# 61      62.0                   Lampur – Narela Road
# 70      71.0   M.G. Road (Mehrauli – Gurugram Road)
# 71      72.0   M.G. Road (Mehrauli – Gurugram Road)
# 82      83.0            Mother Teresa Crescent Marg
# 84      85.0            Mother Teresa Crescent Road
# 85      86.0            Mother Teresa Crescent Road
# 87      88.0            Mother Teresa Crescent Road
# 88      89.0                    Moti Lal Nehru Marg
# 89      90.0                        Mubarakpur Road
# 95      96.0                   Najafgarh Firni Road
# 107    108.0                        Nitya Nand Marg
# 152    153.0                            Road No. 57
# 172    173.0           Shyama Prasad Mukherjee Marg
# 173    174.0           Shyama Prasad Mukherjee Marg
# 174    175.0                      South Avenue Road
# 187    188.0                      Vandemataram Marg
# 188    189.0                Veer Banda Bairagi Marg
# 196    197.0                              DAVP Marg
# 201    202.0                    NH-48 Gurugram Road
# 204    205.0                         J.B. Tito Marg
# 206    207.0  Jhilmil Industrial Area, Railway Road
#
#                                      Specific location  \
# 0            Both carriageway Madhav Rao Schindia Marg
# 24   Near P.S. Timarpur (both carriageway) / Wazira...
# 26                                             W-Point
# 27                                Bhim Gali, Malkaganj
# 28   Drain Road at various locations between Power ...
# 36   Between Dharampura and Iron Bridge / near Iron...
# 37                                Dharampura Seelampur
# 38   Near Seelampur Flyover  (Shastri Park to Shahd...
# 40                                      Shahdara Mandi
# 41                Shastri Park to Shahdara carriageway
# 42                                  Azad Pur underpass
# 44                                  Libaspur Underpass
# 45                                  Near GTK DTC Depot
# 46                    Near Jahangir Puri Metro Station
# 47                              Shakti Nagar underpass
# 53                                  Near Bhinder Point
# 61                                    Lampur Underpass
# 70                           Andheria Mor to M.G. Road
# 71                        Near Jain Mandir Qutub Minar
# 82                 Infront of Gate No. 31, R.P. Bhawan
# 84                        Near RML Hospital roundabout
# 85                                     Near RML U-Turn
# 87   Redlight Sardar Patel Marg towards Ram Manohar...
# 88                         Q-Point Moti Lal Nehru Marg
# 89        Nangloi Railway Phatak to Mubarakpur village
# 95                                          Firni Road
# 107        Near Gate No. 3 Kashmere Gate metro station
# 152                    Bihari Colony Railway underpass
# 172             Exit gate of Old Delhi Railway Station
# 173                                   Near Chhata Rail
# 174                        Both side South Avenue Road
# 187                            Roundabout Shankar Road
# 188                              Azad Market underpass
# 196                                           CISF Cut
# 201                                     Sanjay T-Point
# 204                        Central School Andrewz Ganj
# 206                           Kasturba Nagar Underpass
#
#                                                   Date  Frequency  latitude  \
# 0                                       ['01.09.2021']          1       NaN
# 24                        ['29.07.2021', '01.08.2021']          2       NaN
# 26                                      ['31.08.2021']          1       NaN
# 27                        ['01.08.2021', '01.09.2021']          2       NaN
# 28                                      ['13.07.2021']          1       NaN
# 36   ['03.07.2021', '14.07.2021', '19.07.2021', '29...          5       NaN
# 37                        ['19.07.2021', '28.07.2021']          2       NaN
# 38   ['03.07.2021', '19.07.2021', '28.07.2021', '30...          5       NaN
# 40                                      ['01.08.2021']          1       NaN
# 41                                      ['14.07.2021']          1       NaN
# 42   ['13.07.2021', '14.07.2021', '01.08.2021', '11...          4       NaN
# 44                                      ['11.09.2021']          1       NaN
# 45                        ['03.09.2021', '11.09.2021']          2       NaN
# 46                                      ['11.09.2021']          1       NaN
# 47                                      ['01.08.2021']          1       NaN
# 53                                      ['11.09.2021']          1       NaN
# 61                                      ['11.09.2021']          1       NaN
# 70                                      ['13.07.2021']          1       NaN
# 71                                      ['01.09.2021']          1       NaN
# 82                                      ['02.09.2021']          1       NaN
# 84                                      ['11.09.2021']          1       NaN
# 85                                      ['01.09.2021']          1       NaN
# 87                                      ['13.07.2021']          1       NaN
# 88                                      ['31.08.2021']          1       NaN
# 89                                      ['19.07.2021']          1       NaN
# 95                                      ['19.07.2021']          1       NaN
# 107                                     ['14.07.2021']          1       NaN
# 152                       ['01.08.2021', '11.09.2021']          2       NaN
# 172                                     ['02.09.2021']          1       NaN
# 173         ['14.07.2021', '21.08.2021', '31.08.2021']          3       NaN
# 174                                     ['01.09.2021']          1       NaN
# 187                                     ['08.08.2021']          1       NaN
# 188  ['14.07.2021', '08.08.2021', '21.08.2021', '01...          5       NaN
# 196                                     ['21.08.2021']          1       NaN
# 201                                     ['21.08.2021']          1       NaN
# 204                                     ['21.08.2021']          1       NaN
# 206                                     ['21.08.2021']          1       NaN
#
#      longitude
# 0          NaN
# 24         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 53         NaN
# 61         NaN
# 70         NaN
# 71         NaN
# 82         NaN
# 84         NaN
# 85         NaN
# 87         NaN
# 88         NaN
# 89         NaN
# 95         NaN
# 107        NaN
# 152        NaN
# 172        NaN
# 173        NaN
# 174        NaN
# 187        NaN
# 188        NaN
# 196        NaN
# 201        NaN
# 204        NaN
# 206        NaN

# %%
location = geocode("Kasturba Nagar, Delhi, India")

# %%
location.latitude, location.longitude
# Out:
# (28.5774817, 77.2256295)

# %%
df.loc[df["Sl. No."] == 207, ["latitude", "longitude"]] = [location.latitude, location.longitude]

# %%
df.to_csv("waterlogging_final.csv", index=False)

# %%
df = pd.read_csv("D:\me\CODING\Github\DeepRed\waterlogging_final.csv")

# %%
df = pd.read_csv("D:\me\CODING\Github\DeepRed\waterlogging_final.csv")

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Sl. No., Name of the Road, Specific location, Date, Frequency, latitude, longitude]
# Index: []

# %%
df.describe().to_markdown()
# Out:
# '|       |   Sl. No. |   Frequency |   latitude |   longitude |\n|:------|----------:|------------:|-----------:|------------:|\n| count |  211      |   211       | 211        |  211        |\n| mean  |  106      |     1.4218  |  28.571    |   77.1726   |\n| std   |   61.0546 |     1.07229 |   0.688495 |    0.244838 |\n| min   |    1      |     1       |  18.6553   |   73.7698   |\n| 25%   |   53.5    |     1       |  28.5758   |   77.1417   |\n| 50%   |  106      |     1       |  28.6139   |   77.196    |\n| 75%   |  158.5    |     1       |  28.6547   |   77.2268   |\n| max   |  211      |     7       |  28.8512   |   77.5787   |'

# %%
# !pip install pandas geopandas shapely h3 folium matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (2.3.2)
# Collecting geopandas
#   Downloading geopandas-1.1.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting shapely
#   Downloading shapely-2.1.2-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Collecting h3
#   Downloading h3-4.4.1-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: folium in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (0.20.0)
# Requirement already satisfied: matplotlib in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (3.10.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp311-cp311-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from geopandas) (25.0)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: branca>=0.6.0 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: certifi in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jsk\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (2.5.0)
# Downloading geopandas-1.1.2-py3-none-any.whl (341 kB)
# Downloading shapely-2.1.2-cp311-cp311-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 9.4 MB/s eta 0:00:00
# Downloading h3-4.4.1-cp311-cp311-win_amd64.whl (796 kB)
#    ---------------------------------------- 0.0/796.4 kB ? eta -:--:--
#    ---------------------------------------- 796.4/796.4 kB 3.8 MB/s eta 0:00:00
# Downloading pyogrio-0.12.1-cp311-cp311-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/22.9 MB 8.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.1/22.9 MB 7.7 MB/s eta 0:00:03
#    ------- -------------------------------- 4.2/22.9 MB 7.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 5.8/22.9 MB 6.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 6.8/22.9 MB 6.6 MB/s eta 0:00:03
#    ------------ --------------------------- 7.3/22.9 MB 6.0 MB/s eta 0:00:03
#    -------------- ------------------------- 8.1/22.9 MB 5.6 MB/s eta 0:00:03
#    --------------- ------------------------ 8.9/22.9 MB 5.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 9.7/22.9 MB 5.1 MB/s eta 0:00:03
#    ------------------ --------------------- 10.7/22.9 MB 5.0 MB/s eta 0:00:03
#    ------------------- -------------------- 11.3/22.9 MB 4.9 MB/s eta 0:00:03
#    -------------------- ------------------- 11.8/22.9 MB 4.7 MB/s eta 0:00:03
#    --------------------- ------------------ 12.6/22.9 MB 4.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 13.4/22.9 MB 4.6 MB/s eta 0:00:03
#    ------------------------ --------------- 14.2/22.9 MB 4.4 MB/s eta 0:00:03
#    -------------------------- ------------- 14.9/22.9 MB 4.4 MB/s eta 0:00:02
#    --------------------------- ------------ 16.0/22.9 MB 4.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.0/22.9 MB 4.4 MB/s eta 0:00:02
#    ------------------------------- -------- 18.1/22.9 MB 4.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.7/22.9 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 21.0/22.9 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 22.0/22.9 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 4.6 MB/s eta 0:00:00
# Downloading pyproj-3.7.2-cp311-cp311-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 5.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.3 MB 5.3 MB/s eta 0:00:01
#    ------------------ --------------------- 2.9/6.3 MB 4.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.3 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 4.5 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.3 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 4.0 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, h3, geopandas
#
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    -------- ------------------------------- 1/5 [pyproj]
#    -------- ------------------------------- 1/5 [pyproj]
#    -------- ------------------------------- 1/5 [pyproj]
#    -------- ------------------------------- 1/5 [pyproj]
#    -------- ------------------------------- 1/5 [pyproj]
#    -------- ------------------------------- 1/5 [pyproj]
#    -------- ------------------------------- 1/5 [pyproj]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ------------------------ --------------- 3/5 [h3]
#    ------------------------ --------------- 3/5 [h3]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    -------------------------------- ------- 4/5 [geopandas]
#    ---------------------------------------- 5/5 [geopandas]
#
# Successfully installed geopandas-1.1.2 h3-4.4.1 pyogrio-0.12.1 pyproj-3.7.2 shapely-2.1.2
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon, Point
import h3
import folium
import matplotlib.pyplot as plt

# -----------------------------
# 1) Load your CSV
# -----------------------------
df = pd.read_csv("waterlogging_final.csv")

# -----------------------------
# 2) Combine duplicate coordinates
# -----------------------------
df = df.groupby(["latitude", "longitude"], as_index=False)["Frequency"].sum()

# -----------------------------
# 3) Convert to H3 hexagons
# -----------------------------
resolution = 7  # smaller number = bigger hexagons

df["h3_index"] = df.apply(
    lambda row: h3.latlng_to_cell(row["latitude"], row["longitude"], resolution),
    axis=1
)

# -----------------------------
# 4) Aggregate frequency per hex
# -----------------------------
hex_agg = df.groupby("h3_index")["Frequency"].sum().reset_index()

# -----------------------------
# 5) Convert H3 hex to polygons
# -----------------------------
def h3_to_polygon(h):
    boundary = h3.cell_to_boundary(h)  # returns list of (lat, lon)

    # Convert to (lon, lat) for Shapely
    boundary_lonlat = [(lng, lat) for lat, lng in boundary]

    return Polygon(boundary_lonlat)

hex_agg["geometry"] = hex_agg["h3_index"].apply(h3_to_polygon)

gdf = gpd.GeoDataFrame(hex_agg, geometry="geometry", crs="EPSG:4326")

# -----------------------------
# 6) Assign colors
# -----------------------------
def freq_to_color(f):
    if f == 0:
        return "#351998"  # white
    elif f == 1:
        return "#2ECC71"  # green
    elif 2 <= f <= 3:
        return "#F1C40F"  # yellow
    else:
        return "#E74C3C"  # red

gdf["color"] = gdf["Frequency"].apply(freq_to_color)

# -----------------------------
# 7) SAVE GEOJSON (for JS dashboards)
# -----------------------------
gdf.to_file("hexbin_data.geojson", driver="GeoJSON")

print("Saved GeoJSON → hexbin_data.geojson")

# -----------------------------
# 8) STATIC PNG MAP
# -----------------------------
fig, ax = plt.subplots(figsize=(8, 8))
gdf.plot(ax=ax, color=gdf["color"], edgecolor="black", linewidth=0.2)

ax.set_title("Water-Logging Risk Hexbin Map — Delhi", fontsize=12)
ax.set_axis_off()

plt.savefig("hexbin_map.png", dpi=300, bbox_inches="tight")
plt.close()

print("Saved PNG → hexbin_map.png")

# -----------------------------
# 9) INTERACTIVE HTML MAP
# -----------------------------
center_lat = df["latitude"].mean()
center_lon = df["longitude"].mean()

m = folium.Map(location=[center_lat, center_lon], zoom_start=11)

for _, row in gdf.iterrows():
    geojson = gpd.GeoSeries([row["geometry"]]).__geo_interface__
    folium.GeoJson(
        geojson,
        style_function=lambda x, color=row["color"]: {
            "color": "black",
            "weight": 1,
            "fillColor": color,
            "fillOpacity": 0.6,
        },
        tooltip=f"Frequency: {row['Frequency']}"
    ).add_to(m)

m.save("hexbin_map.html")

print("Saved interactive map → hexbin_map.html")
# Out:
# Saved GeoJSON → hexbin_data.geojson
# Saved PNG → hexbin_map.png
# Saved interactive map → hexbin_map.html
