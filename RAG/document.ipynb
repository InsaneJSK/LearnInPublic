# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={"source": "example.pdf", "author": "John Doe"}
)
doc
# Out:
# Document(metadata={'source': 'example.pdf', 'author': 'John Doe'}, page_content='This is the content of the document.')

# %%
import os
os.makedirs("data", exist_ok=True)

# %%
sample_texts = {
    "doc1.txt": "This is the content of document 1.",
    "doc2.txt": "This is the content of document 2.",
}
for filename, content in sample_texts.items():
    with open(f"data/{filename}", "w") as f:
        f.write(content)

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("data/doc1.txt")
documents = loader.load()

# %%
documents
# Out:
# [Document(metadata={'source': 'data/doc1.txt'}, page_content='This is the content of document 1.')]

# %%
from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader("data", glob="*.txt", loader_cls=TextLoader, show_progress=True)
documents = loader.load()
# Out:
# 100%|██████████| 2/2 [00:00<?, ?it/s]

# %%
documents
# Out:
# [Document(metadata={'source': 'data\\doc1.txt'}, page_content='This is the content of document 1.'),
#  Document(metadata={'source': 'data\\doc2.txt'}, page_content='This is the content of document 2.')]
